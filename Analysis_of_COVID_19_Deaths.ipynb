# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **Importing Covid -19 Deaths Dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7a4abf20-2a0c-4007-a06c-df7b356fd81f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a4abf20-2a0c-4007-a06c-df7b356fd81f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid19_deaths_dataset.csv to covid19_deaths_dataset.csv

# %%
data_set = pd.read_csv("covid19_deaths_dataset.csv")

# %%
data_set.head()
# Out:
#   Province/State Country/Region      Lat  ...  7/10/20  7/11/20  7/12/20
# 0            NaN    Afghanistan  33.0000  ...      971      994     1010
# 1            NaN        Albania  41.1533  ...       85       89       93
# 2            NaN        Algeria  28.0339  ...      996     1004     1011
# 3            NaN        Andorra  42.5063  ...       52       52       52
# 4            NaN         Angola -11.2027  ...       23       23       26
#
# [5 rows x 177 columns]

# %% [markdown]
# **Check the shape of the data frame**

# %%
data_set.shape
# Out:
# (266, 177)

# %% [markdown]
# **Delete the unwanted Coloumns**

# %%
data_set.drop(["Lat","Long"],axis = 1,inplace = True)

# %%
data_set.head()
# Out:
#   Province/State Country/Region  1/22/20  ...  7/10/20  7/11/20  7/12/20
# 0            NaN    Afghanistan        0  ...      971      994     1010
# 1            NaN        Albania        0  ...       85       89       93
# 2            NaN        Algeria        0  ...      996     1004     1011
# 3            NaN        Andorra        0  ...       52       52       52
# 4            NaN         Angola        0  ...       23       23       26
#
# [5 rows x 175 columns]

# %% [markdown]
# **Aggregating the rows by the country**

# %%
data_set_aggregated = data_set.groupby("Country/Region").sum()

# %%
data_set_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  7/10/20  7/11/20  7/12/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...      971      994     1010
# Albania               0        0        0  ...       85       89       93
# Algeria               0        0        0  ...      996     1004     1011
# Andorra               0        0        0  ...       52       52       52
# Angola                0        0        0  ...       23       23       26
#
# [5 rows x 173 columns]

# %%
data_set_aggregated.shape
# Out:
# (188, 173)

# %% [markdown]
# **Visualizing the data related to a specific country**

# %%
data_set_aggregated.loc['India'].plot()
data_set_aggregated.loc["China"].plot()
data_set_aggregated.loc["Italy"].plot()
plt.legend()

# %% [markdown]
# **Calculating a good measure**

# %%
data_set_aggregated.loc["India"][:6].plot()

# %% [markdown]
# **Calculating and plotting the first derivative of the curve**

# %%
data_set_aggregated.loc["India"].diff().plot()

# %% [markdown]
# **Calculating the maximum fatality rate for India,China,Italy**

# %%
data_set_aggregated.loc["India"].diff().max()
# Out:
# 2003.0

# %%
data_set_aggregated.loc["Italy"].diff().max()
# Out:
# 919.0

# %%
data_set_aggregated.loc["China"].diff().max()
# Out:
# 1290.0

# %% [markdown]
# **Caculating the max fatality rate for all the countries**

# %%
countries= list(data_set_aggregated.index)
max_fatality_rate = []
for c in countries:
   max_fatality_rate.append(data_set_aggregated.loc[c].diff().max())
data_set_aggregated["max fatality rate"] = max_fatality_rate

# %%
data_set_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  7/11/20  7/12/20  max fatality rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...      994     1010               42.0
# Albania               0        0        0  ...       89       93                4.0
# Algeria               0        0        0  ...     1004     1011               30.0
# Andorra               0        0        0  ...       52       52                4.0
# Angola                0        0        0  ...       23       26                3.0
#
# [5 rows x 174 columns]

# %% [markdown]
# **Create a new dataframe for max fatality rate**

# %%
corona_fatality_rate = pd.DataFrame(data_set_aggregated["max fatality rate"])

# %%
corona_fatality_rate.head()
# Out:
#                 max fatality rate
# Country/Region
# Afghanistan                  42.0
# Albania                       4.0
# Algeria                      30.0
# Andorra                       4.0
# Angola                        3.0
